# %% [markdown]
# <a href="https://colab.research.google.com/github/Jivang0/machine_learning_all/blob/main/DlyticaPythonBasic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10
b = 20
print( a is b )
# Out:
# False

# %%
numbers = [10, 20, 30, 40]

print(20 in numbers)    # True
print(50 in numbers)    # False
# Out:
# True
# False

# %%
z = 3 + 4j

print(z.real)   # Real part
print(z.imag)   # Imaginary part
# Out:
# 3.0
# 4.0

# %%
x = complex(3, 4)
print(x)
# Out:
# (3+4j)

# %%
data = [10, "Python", 3.14, True]
print(data)
print(type(data))
# Out:
# [10, 'Python', 3.14, True]
# <class 'list'>

# %%
fruits = ["apple", "banana", "mango"]

print(fruits[0])   # a
print(fruits[1])   # b
# Out:
# apple
# banana

# %%
student = {"name": "Ram", "age": 20}

print(student["name"])
print(student["age"])
# Out:
# Ram
# 20

# %%
data1 = (10, "Python", 3.14, True)
print(data1)
print(type(data1))
# Out:
# (10, 'Python', 3.14, True)
# <class 'tuple'>

# %%
numbers = {1, 2, 3, 2, 1}

print(numbers)
# Out:
# {1, 2, 3}
